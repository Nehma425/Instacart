# %% [markdown]
# #import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #import dataframe

# %%
path = r'C:\Instacart Basket Achievement 4 NEW'

# %%
path
# Out:
# 'C:\\Instacart Basket Achievement 4 NEW'

# %%
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
df_orders_products_combined
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                  0   2539329        1             1                   2
# 1                  0   2539329        1             1                   2
# 2                  0   2539329        1             1                   2
# 3                  0   2539329        1             1                   2
# 4                  0   2539329        1             1                   2
# ...              ...       ...      ...           ...                 ...
# 32434484     3421081   2977660   206209            13                   1
# 32434485     3421081   2977660   206209            13                   1
# 32434486     3421081   2977660   206209            13                   1
# 32434487     3421081   2977660   206209            13                   1
# 32434488     3421081   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
df_orders_products_combined['_merge'].value_counts() ## Checking value count of '_merge' in df_orders_products_combined before merging with df_prods
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_orders_products_combined = df_orders_products_combined.drop(columns = ['Unnamed: 0'])# Dropping the extra indexing column "Unnamed: 0"

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data' , 'Prepared Data', 'products_checked_1.csv'), index_col=False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_prods = df_prods.drop(columns = ['Unnamed: 0'])

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_orders_products_merged = df_orders_products_combined.merge(df_prods, on = 'product_id') #merging dataframes

# %%
df_orders_products_merged.shape
# Out:
# (32404859, 14)

# %%
df_orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices
# ...

# %%
df_orders_products_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# There were 32,434,489 rows in the orders_products_combined data frame. There were 49,672 rows in the prods data frame. When merged with an inner join the result was 32,404,859 rows. This is 29,630 fewer records than in the orders_products_combined data frame

# %%
df_orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
